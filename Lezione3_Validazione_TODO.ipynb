# %% [markdown]
# # Lezione 3 — Validazione, overfitting e tuning (TODO)
#
# Completa le celle e interpreta i risultati.

# %% [markdown]
# ## Dataset
# Useriamo il dataset **Breast Cancer Wisconsin**.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ## 1) Caricamento dati

# %%
# TODO:
# carica il dataset, crea df e aggiungi target_name

# %%
# TODO:
# stampa value_counts di target_name

# %% [markdown]
# ## 2) Definizione di X e y

# %%
# TODO: definisci X e y

# %% [markdown]
# ## 3) Train/Test split

# %%
# TODO:
# train_test_split con test_size=0.25, random_state=42, stratify=y

# %% [markdown]
# ## 4) Decision tree: esempio di overfitting

# %%
# TODO:
# addestra un albero con max_depth=None
# stampa accuracy su train e test

# %%
# TODO:
# addestra un albero con max_depth=3
# stampa accuracy su train e test

# %%
# TODO:
# crea una tabella di confronto tra i due modelli

# %% [markdown]
# ### Domande
# 1. Quale modello overfitta di più?
# 2. Cosa osservi confrontando accuracy train e test?

# %% [markdown]
# ## 5) Cross-validation con kNN

# %%
# TODO:
# scala i dati con StandardScaler
# crea un kNN con k=5
# calcola cross_val_score(..., cv=5)
# stampa media e deviazione standard

# %% [markdown]
# ## 6) Grid Search

# %%
# TODO:
# imposta param_grid con n_neighbors e weights
# crea GridSearchCV e allena sul training
# stampa best_params_ e best_score_

# %%
# TODO:
# valuta il best estimator sul test
# stampa accuracy e classification_report

# %%
# TODO:
# crea la confusion matrix come DataFrame

# %% [markdown]
# ## 7) Conclusioni (scrivi 5–8 righe)
# 1. Perché la cross-validation è utile?
# 2. Quali iperparametri sono stati scelti?
# 3. Useresti il modello finale? Perché?
