# %% [markdown]
# # Lezione 4 — Dal neurone artificiale al modello non lineare (TODO)
#
# Completa il notebook e confronta un modello lineare con uno non lineare.

# %% [markdown]
# ## Dataset
# Usiamo `make_moons`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 1) Generazione dati

# %%
# TODO:
#Cercare sulla doc di sklearn come funziona make_moons e quali sono i parametri che accetta
# genera X, y con make_moons(n_samples=1000, noise=0.25, random_state=42)
# crea df con colonne x1, x2, target

# %%
# TODO:
# fai uno scatter plot con colore = target

# %% [markdown]
# ### Domanda
# Osservando il grafico, pensi che un confine lineare sia sufficiente?

# %% [markdown]
# ## 2) Train/Test split + scaling

# %%
# TODO:
# split con test_size=0.25, random_state=42, stratify=target
# poi StandardScaler fit sul train e transform su test

# %% [markdown]
# ## 3) Baseline lineare: Logistic Regression

# %%
# TODO:
# addestra LogisticRegression
# predici sul test
# calcola accuracy

# %% [markdown]
# ## 4) Modello non lineare: MLP

# %%
# TODO:
# addestra MLPClassifier(hidden_layer_sizes=(8, 8), max_iter=2000, random_state=42)
# predici sul test
# calcola accuracy

# %%
# TODO:
# crea una tabella di confronto tra accuracy di Logistic Regression e MLP

# %% [markdown]
# ## 5) Un neurone singolo da zero (NumPy)

# %%
# TODO:
# implementa sigmoid(z)
def sigmoid(z):
    pass

# %%
# TODO:
# implementa train_logreg_numpy(X, y_bin, lr=0.1, epochs=1000)
# Suggerimento:
# 1. aggiungi la colonna di bias
# 2. inizializza i pesi a zero
# 3. y_hat = sigmoid(Xb @ w)
# 4. gradiente = Xb.T @ (y_hat - y_bin) / n
# 5. aggiorna i pesi

def train_logreg_numpy(X, y_bin, lr=0.1, epochs=1000):
    pass

# %%
# TODO:
# allena il neurone sul training
# valuta l'accuracy sul test

# %% [markdown]
# ## 6) Conclusioni (scrivi 5–8 righe)
# 1. Perché il modello lineare fatica?
# 2. Perché l’MLP migliora?
# 3. Cosa rappresentano i pesi del neurone?
# 4. Perché la non linearità è importante?
