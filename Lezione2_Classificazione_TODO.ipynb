# %% [markdown]
# # Lezione 2 — Classificazione supervisionata end-to-end (TODO)
#
# **Obiettivo:** completare una pipeline di classificazione supervisionata sul dataset Wine.
#
# Completa le celle `# TODO` e rispondi alle domande nei blocchi markdown.

# %% [markdown]
# ## Dataset
# Useriamo il dataset **Wine** di `scikit-learn`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

pd.set_option("display.max_columns", 50)

# %% [markdown]
# ## 1) Caricamento dati

# %%
# TODO:
# 1. carica il dataset wine con load_wine(as_frame=True)
# 2. crea un DataFrame df
# 3. aggiungi una colonna class_name con i nomi delle classi
# 4. mostra le prime righe

# %%
# TODO:
# stampa shape e value_counts di class_name

# %% [markdown]
# ### Domande
# 1. Quante classi ci sono?
# 2. Il dataset è bilanciato?
# 3. Qual è il target?

# %% [markdown]
# ## 2) Definizione di X e y

# %%
# TODO:
# X = ... (feature numeriche)
# y = ... (class_name)

# %% [markdown]
# ## 3) Train/Test split

# %%
# TODO:
# fai train_test_split con:
# - test_size=0.25
# - random_state=42
# - stratify=y

# %% [markdown]
# ### Domande
# 1. Perché usiamo `stratify=y`?
# 2. Perché non alleniamo e testiamo sullo stesso insieme di dati?

# %% [markdown]
# ## 4) Scaling

# %%
# TODO:
# 1. crea StandardScaler()
# 2. fit_transform sul train
# 3. transform sul test

# %% [markdown]
# ## 5) Modello 1 — Logistic Regression

# %%
# TODO:
# 1. istanzia LogisticRegression(max_iter=2000)
# 2. addestra il modello
# 3. predici sul test
# 4. calcola accuracy

# %%
# TODO:
# stampa classification_report per Logistic Regression

# %% [markdown]
# ## 6) Modello 2 — kNN

# %%
# TODO:
# ripeti il flusso con KNeighborsClassifier(n_neighbors=5)

# %%
# TODO:
# stampa classification_report per kNN

# %% [markdown]
# ## 7) Confronto modelli

# %%
# TODO:
# crea una tabella results con i nomi dei modelli e le accuracy
# ordina la tabella per accuracy decrescente

# %%
# TODO:
# scegli il modello migliore
# costruisci la confusion matrix come DataFrame

# %% [markdown]
# ## 8) Interpretazione

# %%
# TODO (facoltativo):
# se il modello migliore è Logistic Regression, stampa i coefficienti in un DataFrame

# %% [markdown]
# ## 9) Conclusioni (scrivi 5–8 righe)
# 1. Quale modello scegli?
# 2. Perché?
# 3. Dove sbaglia?
# 4. Quali caratteristiche del dataset possono spiegare gli errori?
