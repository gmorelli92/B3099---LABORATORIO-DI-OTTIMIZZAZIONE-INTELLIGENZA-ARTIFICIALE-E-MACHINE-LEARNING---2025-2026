# %% [markdown]
# # Lezione 5 — CNN per il riconoscimento di immagini (TODO)
#
# Completa il notebook costruendo una CNN minima su MNIST.
#
# > Se necessario: `pip install torch torchvision`

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
from sklearn.metrics import confusion_matrix
import pandas as pd

# %% [markdown]
# ## 1) Dataset MNIST

# %%
# TODO:
# imposta device = cuda se disponibile, altrimenti cpu

# %%
# TODO:
# crea la transform con:
# - ToTensor()
# - Normalize((0.1307,), (0.3081,))
#
# poi scarica train/test MNIST, crea un subset più piccolo
# e i DataLoader

# %%
# TODO:
# visualizza 8 immagini con la loro label

# %% [markdown]
# ## 2) CNN minimale

# %%
# TODO:
# completa la classe SimpleCNN
class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            # TODO: Conv2d(1, 16, ...)
            # TODO: ReLU
            # TODO: MaxPool2d(2)
            # TODO: Conv2d(16, 32, ...)
            # TODO: ReLU
            # TODO: MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            # TODO: Flatten
            # TODO: Linear(32*7*7, 64)
            # TODO: ReLU
            # TODO: Linear(64, 10)
        )

    def forward(self, x):
        # TODO
        pass

# %% [markdown]
# ## 3) Training

# %%
# TODO:
# definisci criterion = nn.CrossEntropyLoss()
# definisci optimizer = torch.optim.Adam(...)

# %%
# TODO:
# completa train_one_epoch:
# - model.train()
# - zero_grad
# - forward
# - loss
# - backward
# - step
# - accuracy

def train_one_epoch(model, loader, optimizer, criterion, device):
    pass

# %%
# TODO:
# esegui 2 epoche e stampa loss/accuracy

# %% [markdown]
# ## 4) Valutazione

# %%
# TODO:
# completa la funzione evaluate e calcola test accuracy

def evaluate(model, loader, device):
    pass

# %%
# TODO:
# calcola e stampa la confusion matrix

# %% [markdown]
# ## 5) Esempi sbagliati

# %%
# TODO:
# mostra alcune immagini classificate male

# %% [markdown]
# ## 6) Conclusioni (scrivi 5–8 righe)
# 1. Che preprocessing abbiamo applicato?
# 2. Qual è il ruolo di convoluzione e pooling?
# 3. Dove sbaglia la CNN?
# 4. Cosa miglioreresti per primo?
